# %% [markdown]
# # Real World Python Data Analysis
#
# Hello, I'm **`Ademola Abraham`**, A **`Health Data Analyst`** and I will be working on a real world Dataset called **`Patients laboratory test results Dataset`**, which is in the CSV format and was gotten from [data.mendeley.com](https://data.mendeley.com/datasets/7kv3rctx7m/1).
#
# I will be using Python data analysis libaries to analyse and visualize the data to get valuable insights, I will also be finding solutions and answers to probelms and questions concerning the dataset.
#
# # Data Description
# The dataset is Electronic Health Record predicting collected from a privatee Hospital in Indonesia. it contains the patients laboratory test results used to determine next patient treatment whether in care or out care patient. it has 11 columns as listed below;
#
# - Haematocrit
#
# - Haemoglobin
# - Erythrocyte
# - Leucocyte
# - Thrombocyte
# - MCH
# - MCHC
# - MCV
# - Age
# - Sex
# - Source
#
#
# ## Importing Python libaries that will be used for analysis and visualization of the dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import os
# %matplotlib inline

# %% [markdown]
# # Data Preparation and Cleaning

# %%
raw_data = pd.read_csv(r'C:\Users\MR ADEMOLA\Desktop\New folder (2)\9\data-ori.csv')
raw_data # Loading the dataset into the jupyter notebook(work space)
# Out:
#       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  \
# 0            35.1          11.8         4.65        6.3          310  25.4
# 1            43.5          14.8         5.39       12.7          334  27.5
# 2            33.5          11.3         4.74       13.2          305  23.8
# 3            39.1          13.7         4.98       10.5          366  27.5
# 4            30.9           9.9         4.23       22.1          333  23.4
# ...           ...           ...          ...        ...          ...   ...
# 4407         32.8          10.4         3.49        8.1           72  29.8
# 4408         33.7          10.8         3.67        6.7           70  29.4
# 4409         33.2          11.2         3.47        7.2          235  32.3
# 4410         31.5          10.4         3.15        9.1          187  33.0
# 4411         33.5          10.9         3.44        5.8          275  31.7
#
#       MCHC    MCV  AGE SEX SOURCE
# ...

# %%
data = raw_data.copy() # making a copy of the original loaded dataet 
data
# Out:
#       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  \
# 0            35.1          11.8         4.65        6.3          310  25.4
# 1            43.5          14.8         5.39       12.7          334  27.5
# 2            33.5          11.3         4.74       13.2          305  23.8
# 3            39.1          13.7         4.98       10.5          366  27.5
# 4            30.9           9.9         4.23       22.1          333  23.4
# ...           ...           ...          ...        ...          ...   ...
# 4407         32.8          10.4         3.49        8.1           72  29.8
# 4408         33.7          10.8         3.67        6.7           70  29.4
# 4409         33.2          11.2         3.47        7.2          235  32.3
# 4410         31.5          10.4         3.15        9.1          187  33.0
# 4411         33.5          10.9         3.44        5.8          275  31.7
#
#       MCHC    MCV  AGE SEX SOURCE
# ...

# %%
data.columns # Checking the names of each column
# Out:
# Index(['HAEMATOCRIT', 'HAEMOGLOBINS', 'ERYTHROCYTE', 'LEUCOCYTE',
#        'THROMBOCYTE', 'MCH', 'MCHC', 'MCV', 'AGE', 'SEX', 'SOURCE'],
#       dtype='object')

# %%
data.shape # Checking the number of rows and columns
# Out:
# (4412, 11)

# %%
data.duplicated().sum() # Checking for duplicated rows(repeated datas) in th dataset
# Out:
# 0

# %%
data.isnull().sum() # Checking for null values in the dataset
# Out:
# HAEMATOCRIT     0
# HAEMOGLOBINS    0
# ERYTHROCYTE     0
# LEUCOCYTE       0
# THROMBOCYTE     0
# MCH             0
# MCHC            0
# MCV             0
# AGE             0
# SEX             0
# SOURCE          0
# dtype: int64

# %%
data.info() # Summary of the datas in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4412 entries, 0 to 4411
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HAEMATOCRIT   4412 non-null   float64
#  1   HAEMOGLOBINS  4412 non-null   float64
#  2   ERYTHROCYTE   4412 non-null   float64
#  3   LEUCOCYTE     4412 non-null   float64
#  4   THROMBOCYTE   4412 non-null   int64
#  5   MCH           4412 non-null   float64
#  6   MCHC          4412 non-null   float64
#  7   MCV           4412 non-null   float64
#  8   AGE           4412 non-null   int64
#  9   SEX           4412 non-null   object
#  10  SOURCE        4412 non-null   object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 379.3+ KB

# %%
# Changing the datatypes of these columns to the appropriate ones

data['SEX'] = data['SEX'].astype('category')
data['SOURCE'] = data['SOURCE'].astype('category')

# %%
data.dtypes # Datatypes of each columns
# Out:
# HAEMATOCRIT      float64
# HAEMOGLOBINS     float64
# ERYTHROCYTE      float64
# LEUCOCYTE        float64
# THROMBOCYTE        int64
# MCH              float64
# MCHC             float64
# MCV              float64
# AGE                int64
# SEX             category
# SOURCE          category
# dtype: object

# %%
data.describe() # Statistical summary of the dataset
# Out:
#        HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE    LEUCOCYTE  THROMBOCYTE  \
# count  4412.000000   4412.000000  4412.000000  4412.000000  4412.000000
# mean     38.197688     12.741727     4.541260     8.718608   257.524479
# std       5.974784      2.079903     0.784091     5.049041   113.972365
# min      13.700000      3.800000     1.480000     1.100000     8.000000
# 25%      34.375000     11.400000     4.040000     5.675000   188.000000
# 50%      38.600000     12.900000     4.570000     7.600000   256.000000
# 75%      42.500000     14.200000     5.050000    10.300000   321.000000
# max      69.000000     18.900000     7.860000    76.600000  1183.000000
#
#                MCH         MCHC          MCV          AGE
# count  4412.000000  4412.000000  4412.000000  4412.000000
# mean     28.234701    33.343042    84.612942    46.626473
# std       2.672639     1.228664     6.859101    21.731218
# min      14.900000    26.000000    54.000000     1.000000
# ...

# %% [markdown]
# # Exploratory Analysis and Visualization

# %%
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (14,7)

# %%
sns.histplot(data=data, x='HAEMATOCRIT', kde=True, color='green', hue='SOURCE')
plt.title('Haematocrit distribution with source')
plt.grid();

# %%
sns.histplot(data=data, x='THROMBOCYTE', kde=True, hue='SOURCE')
plt.title('Thrombocyte distribution with source')
plt.grid();

# %%
sns.histplot(data=data, x='LEUCOCYTE', kde=True, hue='SOURCE')
plt.title('Leucocytes distribution with source')
plt.grid();

# %%
sns.countplot(data=data, x='SOURCE', hue='SEX')
plt.title('Source distribution with sex count')
plt.legend(title='Sex', bbox_to_anchor=(1.15, 1))
plt.grid();

# %%
sns.histplot(data=data, x='AGE', color='purple')
plt.title('Age distribution')
plt.grid();

# %%
sns.scatterplot(data=data, x='AGE', y='MCH', hue='SEX')
plt.title('Relationship of Age and MCH with sex')
plt.legend(title='Sex', bbox_to_anchor=(1.1, 1));

# %%
plt.pie(x=data['SOURCE'].value_counts(), labels=data['SOURCE'].unique(),  explode=[0.05,0], autopct ='%.1f%%')
plt.legend(title='Source', bbox_to_anchor =(1.3, 0.72))
plt.title('Percentage of in and out care patients ');

# %%
plt.figure(figsize=(15,15))

plt.subplot(4,2,1)
sns.histplot(data=data, x='HAEMATOCRIT', hue='SOURCE')
plt.title('Haematocrit distribution')

plt.subplot(4,2,2)
sns.histplot(data=data, x='HAEMOGLOBINS', hue='SOURCE')
plt.title('Haemoglobins distribution')

plt.subplot(4,2,3)
sns.histplot(data=data, x='ERYTHROCYTE', hue='SOURCE')
plt.title('Erythrocyte distribution')

plt.subplot(4,2,4)
sns.histplot(data=data, x='LEUCOCYTE', hue='SOURCE')
plt.title('Leucocyte distribution')

plt.subplot(4,2,5)
sns.histplot(data=data, x='THROMBOCYTE', hue='SOURCE')
plt.title('Thrombocyte distribution')

plt.subplot(4,2,6)
sns.histplot(data=data, x='MCH', hue='SOURCE')
plt.title('MCH distribution')

plt.subplot(4,2,7)
sns.histplot(data=data, x='MCHC', hue='SOURCE')
plt.title('MCHC distribution')

plt.subplot(4,2,8)
sns.histplot(data=data, x='MCV', hue='SOURCE')
plt.title('MCV distribution')

plt.tight_layout()
plt.show();

# %% [markdown]
# # Questions and Answers
#
# ## 1. How many female patients at age 18 and above had a normal Haematocrit level?

# %%
# F=36-48%  M=40-54% sFM=30-44%

a = data[(data['SEX'] == 'F') & (data['AGE'] >= 18) & (data['HAEMATOCRIT'] >= 36) & (data['HAEMATOCRIT'] <= 48)]
a
# Out:
#       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  \
# 441          41.5          13.3         4.83        2.9          217  27.5
# 442          38.9          12.8         4.66        7.7          362  27.5
# 443          38.9          12.6         4.83        9.7          307  26.1
# 444          36.9          12.5         4.16        3.1          207  30.0
# 445          37.2          12.3         4.18        8.3          306  29.4
# ...           ...           ...          ...        ...          ...   ...
# 4353         36.5          12.0         3.63        6.7          249  33.1
# 4366         41.0          13.3         4.49       16.4          293  29.6
# 4372         36.4          11.6         3.92       11.2          267  29.6
# 4375         36.1          12.1         4.19       16.4          271  28.9
# 4399         39.5          12.8         4.18        7.6          337  30.6
#
#       MCHC    MCV  AGE SEX SOURCE
# ...

# %%
a.shape
# Out:
# (1124, 11)

# %%
print("""
How many female patients at age 18 and above had a normal Haematocrit level?
Answer: {} female patients""".format(a.shape[0]))
# Out:
# How many female patients at age 18 and above had a normal Haematocrit level?
# Answer: 1124 female patients

# %% [markdown]
# ## 2. How many patients had a normal MCV?

# %%
#mean corpuscular volume FM=80-100fl femtolitre
b = data[(data['MCV'] >= 80) & (data['MCV'] <= 100)]
b
# Out:
#       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  \
# 1            43.5          14.8         5.39       12.7          334  27.5
# 7            40.3          13.3         4.73        8.1          257  28.1
# 13           35.3          11.9         4.40        5.8          205  27.0
# 30           36.1          11.7         4.51        6.4           85  25.9
# 31           37.3          11.6         4.60        4.1          115  25.2
# ...           ...           ...          ...        ...          ...   ...
# 4407         32.8          10.4         3.49        8.1           72  29.8
# 4408         33.7          10.8         3.67        6.7           70  29.4
# 4409         33.2          11.2         3.47        7.2          235  32.3
# 4410         31.5          10.4         3.15        9.1          187  33.0
# 4411         33.5          10.9         3.44        5.8          275  31.7
#
#       MCHC    MCV  AGE SEX SOURCE
# ...

# %%
b.shape
# Out:
# (3562, 11)

# %%
print("""
How many patients had a normal MCV?
Answer: {} Patients
""".format(b.shape[0]))
# Out:
# How many patients had a normal MCV?
# Answer: 3562 Patients

# %% [markdown]
# ## 3. How many in care patients had a abnormal leucocyte level?

# %%
#sFM<2=6200-17000/mm FM<2=4.5-11.0cells/l
c = data[(data['SOURCE'] == 'in') & (data['LEUCOCYTE'] >= 4.5) & (data['LEUCOCYTE'] <= 11)]
c
# Out:
#       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  \
# 11           54.0          16.6         7.61       10.0           88  21.8
# 12           31.7          10.4         4.91        9.7          348  21.2
# 24           34.6          11.2         4.42        7.0          152  25.3
# 25           34.7          11.5         4.50        5.1          135  25.6
# 27           25.4           8.2         3.27        5.4           90  25.1
# ...           ...           ...          ...        ...          ...   ...
# 4404         31.9          10.3         3.42        8.7          110  30.1
# 4405         28.3           9.2         3.03        8.4          100  30.4
# 4407         32.8          10.4         3.49        8.1           72  29.8
# 4408         33.7          10.8         3.67        6.7           70  29.4
# 4410         31.5          10.4         3.15        9.1          187  33.0
#
#       MCHC    MCV  AGE SEX SOURCE
# ...

# %%
c.shape
# Out:
# (979, 11)

# %%
print("""
How many in care patients had a abnormal leucocyte level?
Answer: {} patients""".format(c.shape[0]))
# Out:
# How many in care patients had a abnormal leucocyte level?
# Answer: 979 patients

# %% [markdown]
# ## 4. How many male patients had a normal Haematocrit level and MCH?

# %%
#27-31picograms/cell
d = data[(data['SEX']=='M')&(data['HAEMATOCRIT']>=40)&(data['HAEMATOCRIT']<=54)&(data['MCH']>=27)&(data['MCH']<=31)]
d
# Out:
#       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  \
# 125          41.4          14.2         5.11        9.5          322  27.8
# 148          43.7          15.1         5.38        8.3          284  28.1
# 160          40.1          13.1         4.85        7.8          321  27.0
# 189          46.4          15.4         5.53        8.3          327  27.8
# 196          41.6          13.7         5.02        8.3          314  27.3
# ...           ...           ...          ...        ...          ...   ...
# 4298         46.3          15.3         5.17       12.2          369  29.6
# 4299         45.2          15.4         5.14       12.5          434  30.0
# 4322         41.8          14.2         4.84        6.1          187  29.3
# 4323         41.3          13.5         4.68       24.8          176  28.8
# 4378         41.1          14.1         4.59        5.9          150  30.7
#
#       MCHC   MCV  AGE SEX SOURCE
# 125   34.3  81.0    5   M    out
# ...

# %%
d.shape
# Out:
# (976, 11)

# %%
print("""
How many male patients had a normal Haematocrit level and MCH?
Answer: {} Patients""".format(d.shape[0]))
# Out:
# How many male patients had a normal Haematocrit level and MCH?
# Answer: 976 Patients

# %% [markdown]
# ## 5. How many in care patients are below age 13?

# %%
e = data[(data['SOURCE'] == 'in')&(data['AGE'] < 13)]
e
# Out:
#      HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  \
# 11          54.0          16.6         7.61       10.0           88  21.8
# 12          31.7          10.4         4.91        9.7          348  21.2
# 23          53.0          16.3         7.54        4.3          112  21.6
# 24          34.6          11.2         4.42        7.0          152  25.3
# 25          34.7          11.5         4.50        5.1          135  25.6
# ..           ...           ...          ...        ...          ...   ...
# 295         43.2          14.2         5.47        3.7           95  26.0
# 301         44.5          15.6         5.41       12.9          387  28.8
# 302         43.4          14.4         5.30        1.8          150  27.2
# 303         45.2          14.7         5.48        2.7          135  26.8
# 304         37.8          13.3         4.58       14.4          395  29.0
#
#      MCHC   MCV  AGE SEX SOURCE
# 11   30.7  71.0    1   F     in
# ...

# %%
e.shape
# Out:
# (113, 11)

# %%
print("""
How many in care patients are below age 13?
Answer: {} Patients""".format(e.shape[0]))
# Out:
# How many in care patients are below age 13?
# Answer: 113 Patients

# %% [markdown]
# # Inferences and Conclusions
#
# > 1. Most in-care patients had a low Haematocrit level with very few having a high Haematocrit level, along with the other test results like Thrombocyte level results.
#
# > 2. This can help Physicians to treat a patient condition effectively by monitoring a patient condition and health information such as Haematocrit level, Mean corpuscular volume etc.
#
# > 3. Most out-care patients had a normal test result with a few of them having a low haematocrit and high Haematocrit level.
#
# > 4. This can help improve efficiencies in work flow by reducing the time required to pull charts, improving access to comprehensive patient data, helping to manage prescriptions, improving scheduling of patient appointments etc.

# %%
data.to_csv(r'C:\Users\MR ADEMOLA\Desktop\New folder (2)\9\cleaned_pltr_data.csv', index=None, header=True)
# Saving the Cleaned modified Dataset in a new CSV file as 'cleaned_pltr_data.csv'

# %%
os.listdir(r'C:\Users\MR ADEMOLA\Desktop\New folder (2)\9')
# Checking for its location to confirmed if it has been saved or not
# Out:
# ['cleaned_pltr_data.csv',
#  'Data Set Information.docx',
#  'data-ori.csv',
#  'excel_prep_cleaned_pltr_data.csv']

# %% [markdown]
# **This marks the end of the analysis on the patients test result dataset!**
